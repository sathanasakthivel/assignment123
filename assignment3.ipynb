# %%
import string
def inpangram(str):
  alphabet="abcdefghijklmnopqrstuvwxyz"
  for char in alphabet:
    if char not in str.lower():
      return false
  return true
  string = 'the rainbow is so beautiful.'
  if (ispangram (string)==true):
    print("yes")
  else:
    print("no")
